# %%
# Import our dependencies
import os
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import numpy as np
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
application_df = pd.read_csv("resources/charity_data.csv")

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])

# %%
# Determine which values to replace if counts are less than ...?
apptype_counts = application_df['APPLICATION_TYPE'].value_counts()
replace_application = list(apptype_counts[apptype_counts < 500].index)

# Replace in dataframe
for app in replace_application:
    application_df.APPLICATION_TYPE = application_df.APPLICATION_TYPE.replace(app,"Other")

# %%
# Determine which values to replace if counts are less than ..?
class_counts = application_df.CLASSIFICATION.value_counts()
replace_class = list(class_counts[class_counts < 1800].index)

# Replace in dataframe
for cls in replace_class:
    application_df.CLASSIFICATION = application_df.CLASSIFICATION.replace(cls,"Other")

# %%
# Generate our categorical variable lists
application_cat = application_df.dtypes[application_df.dtypes == 'object'].index.tolist()

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(application_df[application_cat]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names_out(application_cat)

# %%
# Merge one-hot encoded features and drop the originals
application_df = application_df.merge(encode_df, left_index=True, right_index=True)
application_df = application_df.drop(columns=application_cat)

# %%
# Split our preprocessed data into our features and target arrays
y = application_df['IS_SUCCESSFUL'].values
X = application_df.drop(columns=['IS_SUCCESSFUL', 'STATUS']).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
n_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30

nn1 = tf.keras.models.Sequential()

# First hidden layer
nn1.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=n_features, activation='relu'))

# Second hidden layer
nn1.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Output layer
nn1.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn1.summary()
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3440
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5,901
# Trainable params: 5,901
# Non-trainable params: 0
# _________________________________________________________________
# 2022-01-01 16:07:24.366929: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-01-01 16:07:24.367049: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Compile the model
nn1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
os.makedirs('checkpoints/nn1/', exist_ok=True)

cp_callback = ModelCheckpoint(
    filepath='checkpoints/weights.{epoch:02d}.hdf5',
    verbose=1,
    save_weights_only=True,
    period=5
)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model = nn1.fit(X_train_scaled, y_train, epochs=100, callbacks=[cp_callback])
# Out:
# Epoch 1/100
# 2022-01-01 16:07:24.647063: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-01-01 16:07:24.794324: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5724 - accuracy: 0.7227
# Epoch 2/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5562 - accuracy: 0.7294
# Epoch 3/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5531 - accuracy: 0.7311
# Epoch 4/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5512 - accuracy: 0.7322
# Epoch 5/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5500 - accuracy: 0.7330
# Epoch 00005: saving model to checkpoints/weights.05.hdf5
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5501 - accuracy: 0.7329
# Epoch 6/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5492 - accuracy: 0.7322
# Epoch 7/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5473 - accuracy: 0.7344
# Epoch 8/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5482 - accuracy: 0.7338
# Epoch 9/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5468 - accuracy: 0.7334
# Epoch 10/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5464 - accuracy: 0.7350
# Epoch 00010: saving model to checkpoints/weights.10.hdf5
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5465 - accuracy: 0.7348
# Epoch 11/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5457 - accuracy: 0.7355
# Epoch 12/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5462 - accuracy: 0.7341
# Epoch 13/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5451 - accuracy: 0.7345
# Epoch 14/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5456 - accuracy: 0.7352
# Epoch 15/100
# 796/804 [============================>.] - ETA: 0s - loss: 0.5445 - accuracy: 0.7369
# Epoch 00015: saving model to checkpoints/weights.15.hdf5
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5450 - accuracy: 0.7365
# Epoch 16/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5447 - accuracy: 0.7358
# Epoch 17/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5446 - accuracy: 0.7358
# Epoch 18/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5438 - accuracy: 0.7344
# Epoch 19/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5443 - accuracy: 0.7360
# Epoch 20/100
# 795/804 [============================>.] - ETA: 0s - loss: 0.5429 - accuracy: 0.7368
# Epoch 00020: saving model to checkpoints/weights.20.hdf5
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5430 - accuracy: 0.7368
# Epoch 21/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5436 - accuracy: 0.7367
# Epoch 22/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5429 - accuracy: 0.7366
# Epoch 23/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5431 - accuracy: 0.7378
# Epoch 24/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5427 - accuracy: 0.7371
# Epoch 25/100
# 797/804 [============================>.] - ETA: 0s - loss: 0.5421 - accuracy: 0.7380
# Epoch 00025: saving model to checkpoints/weights.25.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5422 - accuracy: 0.7378
# Epoch 26/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5421 - accuracy: 0.7369
# Epoch 27/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5419 - accuracy: 0.7378
# Epoch 28/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5418 - accuracy: 0.7381
# Epoch 29/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5416 - accuracy: 0.7375
# Epoch 30/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5414 - accuracy: 0.7377
# Epoch 00030: saving model to checkpoints/weights.30.hdf5
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5414 - accuracy: 0.7377
# Epoch 31/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5417 - accuracy: 0.7374
# Epoch 32/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5413 - accuracy: 0.7383
# Epoch 33/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5413 - accuracy: 0.7393
# Epoch 34/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5412 - accuracy: 0.7381
# Epoch 35/100
# 798/804 [============================>.] - ETA: 0s - loss: 0.5413 - accuracy: 0.7380
# Epoch 00035: saving model to checkpoints/weights.35.hdf5
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5412 - accuracy: 0.7381
# Epoch 36/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5403 - accuracy: 0.7391
# Epoch 37/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5405 - accuracy: 0.7390
# Epoch 38/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5400 - accuracy: 0.7397
# Epoch 39/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5399 - accuracy: 0.7381
# Epoch 40/100
# 800/804 [============================>.] - ETA: 0s - loss: 0.5395 - accuracy: 0.7393
# Epoch 00040: saving model to checkpoints/weights.40.hdf5
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5400 - accuracy: 0.7388
# Epoch 41/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5401 - accuracy: 0.7390
# Epoch 42/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5402 - accuracy: 0.7386
# Epoch 43/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5397 - accuracy: 0.7383
# Epoch 44/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5395 - accuracy: 0.7390
# Epoch 45/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5394 - accuracy: 0.7391
# Epoch 00045: saving model to checkpoints/weights.45.hdf5
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5394 - accuracy: 0.7392
# Epoch 46/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5392 - accuracy: 0.7400
# Epoch 47/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5395 - accuracy: 0.7395
# Epoch 48/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5393 - accuracy: 0.7396
# Epoch 49/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5391 - accuracy: 0.7401
# Epoch 50/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5386 - accuracy: 0.7401
# Epoch 00050: saving model to checkpoints/weights.50.hdf5
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5387 - accuracy: 0.7400
# Epoch 51/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5388 - accuracy: 0.7391
# Epoch 52/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5389 - accuracy: 0.7397
# Epoch 53/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5387 - accuracy: 0.7397
# Epoch 54/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5386 - accuracy: 0.7399
# Epoch 55/100
# 800/804 [============================>.] - ETA: 0s - loss: 0.5385 - accuracy: 0.7397
# Epoch 00055: saving model to checkpoints/weights.55.hdf5
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5384 - accuracy: 0.7398
# Epoch 56/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5387 - accuracy: 0.7399
# Epoch 57/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5385 - accuracy: 0.7393
# Epoch 58/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5381 - accuracy: 0.7395
# Epoch 59/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5381 - accuracy: 0.7393
# Epoch 60/100
# 798/804 [============================>.] - ETA: 0s - loss: 0.5379 - accuracy: 0.7397
# Epoch 00060: saving model to checkpoints/weights.60.hdf5
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5380 - accuracy: 0.7397
# Epoch 61/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5382 - accuracy: 0.7394
# Epoch 62/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5377 - accuracy: 0.7400
# Epoch 63/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5380 - accuracy: 0.7397
# Epoch 64/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5376 - accuracy: 0.7390
# Epoch 65/100
# 800/804 [============================>.] - ETA: 0s - loss: 0.5375 - accuracy: 0.7393
# Epoch 00065: saving model to checkpoints/weights.65.hdf5
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5377 - accuracy: 0.7394
# Epoch 66/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5372 - accuracy: 0.7405
# Epoch 67/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5377 - accuracy: 0.7386
# Epoch 68/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5376 - accuracy: 0.7397
# Epoch 69/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5375 - accuracy: 0.7396
# Epoch 70/100
# 804/804 [==============================] - ETA: 0s - loss: 0.5378 - accuracy: 0.7399
# Epoch 00070: saving model to checkpoints/weights.70.hdf5
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5378 - accuracy: 0.7399
# Epoch 71/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5375 - accuracy: 0.7406
# Epoch 72/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5377 - accuracy: 0.7400
# Epoch 73/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5372 - accuracy: 0.7409
# Epoch 74/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5369 - accuracy: 0.7404
# Epoch 75/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5371 - accuracy: 0.7410
# Epoch 00075: saving model to checkpoints/weights.75.hdf5
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5371 - accuracy: 0.7411
# Epoch 76/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5371 - accuracy: 0.7406
# Epoch 77/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5373 - accuracy: 0.7409
# Epoch 78/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5367 - accuracy: 0.7406
# Epoch 79/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5370 - accuracy: 0.7404
# Epoch 80/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5370 - accuracy: 0.7408
# Epoch 00080: saving model to checkpoints/weights.80.hdf5
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5367 - accuracy: 0.7410
# Epoch 81/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5367 - accuracy: 0.7408
# Epoch 82/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5369 - accuracy: 0.7406
# Epoch 83/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5369 - accuracy: 0.7411
# Epoch 84/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5363 - accuracy: 0.7402
# Epoch 85/100
# 797/804 [============================>.] - ETA: 0s - loss: 0.5371 - accuracy: 0.7402
# Epoch 00085: saving model to checkpoints/weights.85.hdf5
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5368 - accuracy: 0.7406
# Epoch 86/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5366 - accuracy: 0.7406
# Epoch 87/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5364 - accuracy: 0.7405
# Epoch 88/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5367 - accuracy: 0.7409
# Epoch 89/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5369 - accuracy: 0.7409
# Epoch 90/100
# 797/804 [============================>.] - ETA: 0s - loss: 0.5364 - accuracy: 0.7409
# Epoch 00090: saving model to checkpoints/weights.90.hdf5
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5362 - accuracy: 0.7411
# Epoch 91/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5362 - accuracy: 0.7409
# Epoch 92/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5360 - accuracy: 0.7405
# Epoch 93/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5362 - accuracy: 0.7405
# Epoch 94/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5357 - accuracy: 0.7411
# Epoch 95/100
# 795/804 [============================>.] - ETA: 0s - loss: 0.5360 - accuracy: 0.7416
# Epoch 00095: saving model to checkpoints/weights.95.hdf5
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5364 - accuracy: 0.7412
# Epoch 96/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5361 - accuracy: 0.7410
# Epoch 97/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5360 - accuracy: 0.7408
# Epoch 98/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5357 - accuracy: 0.7408
# Epoch 99/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5365 - accuracy: 0.7411
# Epoch 100/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5356 - accuracy: 0.7402
# Epoch 00100: saving model to checkpoints/weights.100.hdf5
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5355 - accuracy: 0.7403

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn1.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 2022-01-01 16:14:48.550367: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 268/268 - 1s - loss: 0.5540 - accuracy: 0.7251 - 909ms/epoch - 3ms/step
# Loss: 0.554018497467041, Accuracy: 0.7251311540603638

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
n_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 160
hidden_nodes_layer2 = 40
hidden_nodes_layer3 = 80

nn2 = tf.keras.models.Sequential()

# First hidden layer
nn2.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=n_features, activation='relu'))

# Second hidden layer
nn2.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Third hidden layer
nn2.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='relu'))

# Output layer
nn2.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn2.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_26 (Dense)            (None, 160)               6880
#
#  dense_27 (Dense)            (None, 40)                6440
#
#  dense_28 (Dense)            (None, 80)                3280
#
#  dense_29 (Dense)            (None, 1)                 81
#
# =================================================================
# Total params: 16,681
# Trainable params: 16,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
os.makedirs('checkpoints/nn2/', exist_ok=True)

cp_callback = ModelCheckpoint(
    filepath='checkpoints/weights.{epoch:02d}.hdf5',
    verbose=1,
    save_weights_only=True,
    period=5
)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model = nn2.fit(X_train_scaled, y_train, epochs=100, callbacks=[cp_callback])
# Out:
# Epoch 1/100
#   1/804 [..............................] - ETA: 3:52 - loss: 0.7324 - accuracy: 0.3750
# 2022-01-01 16:45:28.413091: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5676 - accuracy: 0.7250
# Epoch 2/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5561 - accuracy: 0.7308
# Epoch 3/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5527 - accuracy: 0.7322
# Epoch 4/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5508 - accuracy: 0.7331
# Epoch 5/100
# 800/804 [============================>.] - ETA: 0s - loss: 0.5500 - accuracy: 0.7321
# Epoch 00005: saving model to checkpoints/weights.05.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5498 - accuracy: 0.7325
# Epoch 6/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5485 - accuracy: 0.7342
# Epoch 7/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5482 - accuracy: 0.7352
# Epoch 8/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5477 - accuracy: 0.7357
# Epoch 9/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5470 - accuracy: 0.7352
# Epoch 10/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5468 - accuracy: 0.7353
# Epoch 00010: saving model to checkpoints/weights.10.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5468 - accuracy: 0.7356
# Epoch 11/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5458 - accuracy: 0.7370
# Epoch 12/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5456 - accuracy: 0.7362
# Epoch 13/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5450 - accuracy: 0.7367
# Epoch 14/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5446 - accuracy: 0.7370
# Epoch 15/100
# 796/804 [============================>.] - ETA: 0s - loss: 0.5430 - accuracy: 0.7370
# Epoch 00015: saving model to checkpoints/weights.15.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5430 - accuracy: 0.7371
# Epoch 16/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5436 - accuracy: 0.7376
# Epoch 17/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5439 - accuracy: 0.7367
# Epoch 18/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5432 - accuracy: 0.7383
# Epoch 19/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5427 - accuracy: 0.7368
# Epoch 20/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5424 - accuracy: 0.7368
# Epoch 00020: saving model to checkpoints/weights.20.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5424 - accuracy: 0.7368
# Epoch 21/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5425 - accuracy: 0.7380
# Epoch 22/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5421 - accuracy: 0.7379
# Epoch 23/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5420 - accuracy: 0.7375
# Epoch 24/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5418 - accuracy: 0.7386
# Epoch 25/100
# 799/804 [============================>.] - ETA: 0s - loss: 0.5413 - accuracy: 0.7383
# Epoch 00025: saving model to checkpoints/weights.25.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5411 - accuracy: 0.7385
# Epoch 26/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5410 - accuracy: 0.7390
# Epoch 27/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5406 - accuracy: 0.7383
# Epoch 28/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5404 - accuracy: 0.7386
# Epoch 29/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5407 - accuracy: 0.7393
# Epoch 30/100
# 800/804 [============================>.] - ETA: 0s - loss: 0.5405 - accuracy: 0.7379
# Epoch 00030: saving model to checkpoints/weights.30.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5404 - accuracy: 0.7378
# Epoch 31/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5402 - accuracy: 0.7385
# Epoch 32/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5401 - accuracy: 0.7391
# Epoch 33/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5398 - accuracy: 0.7397
# Epoch 34/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5394 - accuracy: 0.7397
# Epoch 35/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5395 - accuracy: 0.7395
# Epoch 00035: saving model to checkpoints/weights.35.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5394 - accuracy: 0.7394
# Epoch 36/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5394 - accuracy: 0.7393
# Epoch 37/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5392 - accuracy: 0.7397
# Epoch 38/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5386 - accuracy: 0.7391
# Epoch 39/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5385 - accuracy: 0.7392
# Epoch 40/100
# 800/804 [============================>.] - ETA: 0s - loss: 0.5390 - accuracy: 0.7395
# Epoch 00040: saving model to checkpoints/weights.40.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5389 - accuracy: 0.7393
# Epoch 41/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5383 - accuracy: 0.7399
# Epoch 42/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5389 - accuracy: 0.7400
# Epoch 43/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5382 - accuracy: 0.7398
# Epoch 44/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5379 - accuracy: 0.7392
# Epoch 45/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5383 - accuracy: 0.7402
# Epoch 00045: saving model to checkpoints/weights.45.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5383 - accuracy: 0.7401
# Epoch 46/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5382 - accuracy: 0.7397
# Epoch 47/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5374 - accuracy: 0.7398
# Epoch 48/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5376 - accuracy: 0.7406
# Epoch 49/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5372 - accuracy: 0.7398
# Epoch 50/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5369 - accuracy: 0.7407
# Epoch 00050: saving model to checkpoints/weights.50.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5370 - accuracy: 0.7407
# Epoch 51/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5375 - accuracy: 0.7409
# Epoch 52/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5369 - accuracy: 0.7404
# Epoch 53/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5371 - accuracy: 0.7414
# Epoch 54/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5370 - accuracy: 0.7400
# Epoch 55/100
# 800/804 [============================>.] - ETA: 0s - loss: 0.5372 - accuracy: 0.7403
# Epoch 00055: saving model to checkpoints/weights.55.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5373 - accuracy: 0.7402
# Epoch 56/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5371 - accuracy: 0.7403
# Epoch 57/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5366 - accuracy: 0.7407
# Epoch 58/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5374 - accuracy: 0.7393
# Epoch 59/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5363 - accuracy: 0.7409
# Epoch 60/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5368 - accuracy: 0.7403
# Epoch 00060: saving model to checkpoints/weights.60.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5367 - accuracy: 0.7403
# Epoch 61/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5364 - accuracy: 0.7407
# Epoch 62/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5362 - accuracy: 0.7411
# Epoch 63/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5361 - accuracy: 0.7409
# Epoch 64/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5357 - accuracy: 0.7408
# Epoch 65/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5363 - accuracy: 0.7407
# Epoch 00065: saving model to checkpoints/weights.65.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5362 - accuracy: 0.7408
# Epoch 66/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5357 - accuracy: 0.7405
# Epoch 67/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5360 - accuracy: 0.7405
# Epoch 68/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5357 - accuracy: 0.7404
# Epoch 69/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5356 - accuracy: 0.7407
# Epoch 70/100
# 797/804 [============================>.] - ETA: 0s - loss: 0.5351 - accuracy: 0.7410
# Epoch 00070: saving model to checkpoints/weights.70.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5355 - accuracy: 0.7407
# Epoch 71/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5369 - accuracy: 0.7406
# Epoch 72/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5355 - accuracy: 0.7411
# Epoch 73/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5345 - accuracy: 0.7411
# Epoch 74/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5351 - accuracy: 0.7411
# Epoch 75/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5352 - accuracy: 0.7409
# Epoch 00075: saving model to checkpoints/weights.75.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5350 - accuracy: 0.7411
# Epoch 76/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5347 - accuracy: 0.7413
# Epoch 77/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5344 - accuracy: 0.7418
# Epoch 78/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5352 - accuracy: 0.7406
# Epoch 79/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5347 - accuracy: 0.7417
# Epoch 80/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5352 - accuracy: 0.7414
# Epoch 00080: saving model to checkpoints/weights.80.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5349 - accuracy: 0.7417
# Epoch 81/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5346 - accuracy: 0.7414
# Epoch 82/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5352 - accuracy: 0.7410
# Epoch 83/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5350 - accuracy: 0.7405
# Epoch 84/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5354 - accuracy: 0.7412
# Epoch 85/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5349 - accuracy: 0.7409
# Epoch 00085: saving model to checkpoints/weights.85.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5346 - accuracy: 0.7411
# Epoch 86/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5342 - accuracy: 0.7421
# Epoch 87/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5343 - accuracy: 0.7415
# Epoch 88/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5350 - accuracy: 0.7411
# Epoch 89/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5344 - accuracy: 0.7412
# Epoch 90/100
# 800/804 [============================>.] - ETA: 0s - loss: 0.5340 - accuracy: 0.7423
# Epoch 00090: saving model to checkpoints/weights.90.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5340 - accuracy: 0.7423
# Epoch 91/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5337 - accuracy: 0.7416
# Epoch 92/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5343 - accuracy: 0.7409
# Epoch 93/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5344 - accuracy: 0.7413
# Epoch 94/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5339 - accuracy: 0.7411
# Epoch 95/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5337 - accuracy: 0.7421
# Epoch 00095: saving model to checkpoints/weights.95.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5339 - accuracy: 0.7419
# Epoch 96/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5338 - accuracy: 0.7419
# Epoch 97/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5345 - accuracy: 0.7416
# Epoch 98/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5339 - accuracy: 0.7415
# Epoch 99/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5335 - accuracy: 0.7419
# Epoch 100/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5336 - accuracy: 0.7417
# Epoch 00100: saving model to checkpoints/weights.100.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5337 - accuracy: 0.7416

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 2022-01-01 16:53:33.122947: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 268/268 - 1s - loss: 0.5686 - accuracy: 0.7254 - 958ms/epoch - 4ms/step
# Loss: 0.5686084032058716, Accuracy: 0.7253644466400146

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
n_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 160
hidden_nodes_layer2 = 80
hidden_nodes_layer3 = 40
hidden_nodes_layer4 = 20

nn3 = tf.keras.models.Sequential()

# First hidden layer
nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=n_features, activation='selu'))

# Second hidden layer
nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='selu'))

# Third hidden layer
nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='selu'))

# Fourth hidden layer
nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation='selu'))

# Output layer
nn3.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn3.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_40 (Dense)            (None, 160)               6880
#
#  dense_41 (Dense)            (None, 80)                12880
#
#  dense_42 (Dense)            (None, 40)                3240
#
#  dense_43 (Dense)            (None, 20)                820
#
#  dense_44 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 23,841
# Trainable params: 23,841
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn3.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
os.makedirs('checkpoints/nn3/', exist_ok=True)

cp_callback = ModelCheckpoint(
    filepath='checkpoints/weights.{epoch:02d}.hdf5',
    verbose=1,
    save_weights_only=True,
    period=5
)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model = nn3.fit(X_train_scaled, y_train, epochs=100, callbacks=[cp_callback])
# Out:
# Epoch 1/100
#   1/804 [..............................] - ETA: 4:22 - loss: 1.0974 - accuracy: 0.3125
# 2022-01-01 16:56:48.174381: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 804/804 [==============================] - 11s 13ms/step - loss: 0.5812 - accuracy: 0.7163
# Epoch 2/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5619 - accuracy: 0.7244
# Epoch 3/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5608 - accuracy: 0.7259
# Epoch 4/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5573 - accuracy: 0.7283
# Epoch 5/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5565 - accuracy: 0.7285
# Epoch 00005: saving model to checkpoints/weights.05.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5564 - accuracy: 0.7285
# Epoch 6/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5568 - accuracy: 0.7286
# Epoch 7/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5557 - accuracy: 0.7292
# Epoch 8/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5544 - accuracy: 0.7293
# Epoch 9/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5534 - accuracy: 0.7302
# Epoch 10/100
# 804/804 [==============================] - ETA: 0s - loss: 0.5527 - accuracy: 0.7318
# Epoch 00010: saving model to checkpoints/weights.10.hdf5
# 804/804 [==============================] - 11s 13ms/step - loss: 0.5527 - accuracy: 0.7318
# Epoch 11/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.5521 - accuracy: 0.7317
# Epoch 12/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5511 - accuracy: 0.7320
# Epoch 13/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5500 - accuracy: 0.7329
# Epoch 14/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5505 - accuracy: 0.7304
# Epoch 15/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5506 - accuracy: 0.7326
# Epoch 00015: saving model to checkpoints/weights.15.hdf5
# 804/804 [==============================] - 11s 13ms/step - loss: 0.5503 - accuracy: 0.7329
# Epoch 16/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5492 - accuracy: 0.7333
# Epoch 17/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5484 - accuracy: 0.7324
# Epoch 18/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5482 - accuracy: 0.7326
# Epoch 19/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5488 - accuracy: 0.7336
# Epoch 20/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5480 - accuracy: 0.7328
# Epoch 00020: saving model to checkpoints/weights.20.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5480 - accuracy: 0.7328
# Epoch 21/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5472 - accuracy: 0.7354
# Epoch 22/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5467 - accuracy: 0.7351
# Epoch 23/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5467 - accuracy: 0.7350
# Epoch 24/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5459 - accuracy: 0.7347
# Epoch 25/100
# 804/804 [==============================] - ETA: 0s - loss: 0.5454 - accuracy: 0.7347
# Epoch 00025: saving model to checkpoints/weights.25.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5454 - accuracy: 0.7347
# Epoch 26/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5451 - accuracy: 0.7355
# Epoch 27/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5456 - accuracy: 0.7340
# Epoch 28/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5449 - accuracy: 0.7350
# Epoch 29/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5451 - accuracy: 0.7359
# Epoch 30/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5448 - accuracy: 0.7353
# Epoch 00030: saving model to checkpoints/weights.30.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5443 - accuracy: 0.7357
# Epoch 31/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5440 - accuracy: 0.7350
# Epoch 32/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5438 - accuracy: 0.7361
# Epoch 33/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5433 - accuracy: 0.7377
# Epoch 34/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.5435 - accuracy: 0.7355
# Epoch 35/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5426 - accuracy: 0.7367
# Epoch 00035: saving model to checkpoints/weights.35.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5425 - accuracy: 0.7367
# Epoch 36/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5431 - accuracy: 0.7364
# Epoch 37/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5425 - accuracy: 0.7367
# Epoch 38/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5423 - accuracy: 0.7376
# Epoch 39/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5422 - accuracy: 0.7375
# Epoch 40/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5421 - accuracy: 0.7371
# Epoch 00040: saving model to checkpoints/weights.40.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5421 - accuracy: 0.7371
# Epoch 41/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5417 - accuracy: 0.7390
# Epoch 42/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5418 - accuracy: 0.7372
# Epoch 43/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5411 - accuracy: 0.7383
# Epoch 44/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5410 - accuracy: 0.7368
# Epoch 45/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5406 - accuracy: 0.7369
# Epoch 00045: saving model to checkpoints/weights.45.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5407 - accuracy: 0.7368
# Epoch 46/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5416 - accuracy: 0.7378
# Epoch 47/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5404 - accuracy: 0.7379
# Epoch 48/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5405 - accuracy: 0.7377
# Epoch 49/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5403 - accuracy: 0.7388
# Epoch 50/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5405 - accuracy: 0.7382
# Epoch 00050: saving model to checkpoints/weights.50.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5404 - accuracy: 0.7383
# Epoch 51/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5400 - accuracy: 0.7383
# Epoch 52/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5400 - accuracy: 0.7387
# Epoch 53/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5402 - accuracy: 0.7384
# Epoch 54/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5400 - accuracy: 0.7382
# Epoch 55/100
# 804/804 [==============================] - ETA: 0s - loss: 0.5398 - accuracy: 0.7390
# Epoch 00055: saving model to checkpoints/weights.55.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5398 - accuracy: 0.7390
# Epoch 56/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.5401 - accuracy: 0.7387
# Epoch 57/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5397 - accuracy: 0.7386
# Epoch 58/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5390 - accuracy: 0.7396
# Epoch 59/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5389 - accuracy: 0.7393
# Epoch 60/100
# 804/804 [==============================] - ETA: 0s - loss: 0.5391 - accuracy: 0.7393
# Epoch 00060: saving model to checkpoints/weights.60.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5391 - accuracy: 0.7393
# Epoch 61/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5383 - accuracy: 0.7397
# Epoch 62/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5385 - accuracy: 0.7379
# Epoch 63/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5386 - accuracy: 0.7386
# Epoch 64/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5379 - accuracy: 0.7401
# Epoch 65/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5393 - accuracy: 0.7391
# Epoch 00065: saving model to checkpoints/weights.65.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5391 - accuracy: 0.7392
# Epoch 66/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5384 - accuracy: 0.7391
# Epoch 67/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5379 - accuracy: 0.7387
# Epoch 68/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5386 - accuracy: 0.7394
# Epoch 69/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5379 - accuracy: 0.7392
# Epoch 70/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5374 - accuracy: 0.7402
# Epoch 00070: saving model to checkpoints/weights.70.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5374 - accuracy: 0.7402
# Epoch 71/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5381 - accuracy: 0.7398
# Epoch 72/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5381 - accuracy: 0.7383
# Epoch 73/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5376 - accuracy: 0.7392
# Epoch 74/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5378 - accuracy: 0.7395
# Epoch 75/100
# 804/804 [==============================] - ETA: 0s - loss: 0.5375 - accuracy: 0.7399
# Epoch 00075: saving model to checkpoints/weights.75.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5375 - accuracy: 0.7399
# Epoch 76/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5371 - accuracy: 0.7395
# Epoch 77/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5413 - accuracy: 0.7386
# Epoch 78/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5371 - accuracy: 0.7401
# Epoch 79/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.5367 - accuracy: 0.7401
# Epoch 80/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5366 - accuracy: 0.7407
# Epoch 00080: saving model to checkpoints/weights.80.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5366 - accuracy: 0.7406
# Epoch 81/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5366 - accuracy: 0.7405
# Epoch 82/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5364 - accuracy: 0.7406
# Epoch 83/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5369 - accuracy: 0.7406
# Epoch 84/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5371 - accuracy: 0.7400
# Epoch 85/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5370 - accuracy: 0.7405
# Epoch 00085: saving model to checkpoints/weights.85.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5369 - accuracy: 0.7406
# Epoch 86/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5366 - accuracy: 0.7414
# Epoch 87/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5374 - accuracy: 0.7403
# Epoch 88/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5366 - accuracy: 0.7405
# Epoch 89/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5375 - accuracy: 0.7398
# Epoch 90/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5362 - accuracy: 0.7409
# Epoch 00090: saving model to checkpoints/weights.90.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5363 - accuracy: 0.7407
# Epoch 91/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5364 - accuracy: 0.7406
# Epoch 92/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5370 - accuracy: 0.7401
# Epoch 93/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5365 - accuracy: 0.7404
# Epoch 94/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5364 - accuracy: 0.7400
# Epoch 95/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5365 - accuracy: 0.7404
# Epoch 00095: saving model to checkpoints/weights.95.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5364 - accuracy: 0.7404
# Epoch 96/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5358 - accuracy: 0.7409
# Epoch 97/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5363 - accuracy: 0.7398
# Epoch 98/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5362 - accuracy: 0.7402
# Epoch 99/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5357 - accuracy: 0.7407
# Epoch 100/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5374 - accuracy: 0.7396
# Epoch 00100: saving model to checkpoints/weights.100.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5371 - accuracy: 0.7399

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 2022-01-01 17:14:09.590517: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 268/268 - 2s - loss: 0.5563 - accuracy: 0.7266 - 2s/epoch - 6ms/step
# Loss: 0.5563240647315979, Accuracy: 0.7266471982002258

# %%
# Import and read the charity_data.csv.
application_df = pd.read_csv("resources/charity_data.csv")

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])

# %%
# Determine which values to replace if counts are less than ...?
apptype_counts = application_df['APPLICATION_TYPE'].value_counts()
replace_application = list(apptype_counts[apptype_counts < 16].index)

# Replace in dataframe
for app in replace_application:
    application_df.APPLICATION_TYPE = application_df.APPLICATION_TYPE.replace(app,"Other")

# %%
# Determine which values to replace if counts are less than ..?
class_counts = application_df.CLASSIFICATION.value_counts()
replace_class = list(class_counts[class_counts < 50].index)

# Replace in dataframe
for cls in replace_class:
    application_df.CLASSIFICATION = application_df.CLASSIFICATION.replace(cls,"Other")

# %%
# Generate our categorical variable lists
application_cat = application_df.dtypes[application_df.dtypes == 'object'].index.tolist()

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(application_df[application_cat]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names_out(application_cat)

# %%
# Merge one-hot encoded features and drop the originals
application_df = application_df.merge(encode_df, left_index=True, right_index=True)
application_df = application_df.drop(columns=application_cat)

# %%
# Split our preprocessed data into our features and target arrays
y = application_df['IS_SUCCESSFUL'].values
X = application_df.drop(columns=['IS_SUCCESSFUL', 'STATUS']).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
n_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 160
hidden_nodes_layer2 = 80
# hidden_nodes_layer3 = 40
# hidden_nodes_layer4 = 20

nn4 = tf.keras.models.Sequential()

# First hidden layer
nn4.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=n_features, activation='selu'))

# Second hidden layer
nn4.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='selu'))

# # Third hidden layer
# nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='selu'))

# # Fourth hidden layer
# nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation='selu'))

# Output layer
nn4.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn4.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_45 (Dense)            (None, 160)               9120
#
#  dense_46 (Dense)            (None, 80)                12880
#
#  dense_47 (Dense)            (None, 1)                 81
#
# =================================================================
# Total params: 22,081
# Trainable params: 22,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn4.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
os.makedirs('checkpoints/nn4/', exist_ok=True)

cp_callback = ModelCheckpoint(
    filepath='checkpoints/weights.{epoch:02d}.hdf5',
    verbose=1,
    save_weights_only=True,
    period=5
)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model = nn4.fit(X_train_scaled, y_train, epochs=50, callbacks=[cp_callback])
# Out:
# Epoch 1/50
#   1/804 [..............................] - ETA: 3:47 - loss: 0.7222 - accuracy: 0.4375
# 2022-01-01 17:25:55.043474: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 804/804 [==============================] - 8s 10ms/step - loss: 0.5878 - accuracy: 0.7152
# Epoch 2/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5644 - accuracy: 0.7257
# Epoch 3/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5593 - accuracy: 0.7272
# Epoch 4/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5552 - accuracy: 0.7298
# Epoch 5/50
# 804/804 [==============================] - ETA: 0s - loss: 0.5542 - accuracy: 0.7318
# Epoch 00005: saving model to checkpoints/weights.05.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5542 - accuracy: 0.7318
# Epoch 6/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5527 - accuracy: 0.7306
# Epoch 7/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5515 - accuracy: 0.7304
# Epoch 8/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5505 - accuracy: 0.7311
# Epoch 9/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5503 - accuracy: 0.7318
# Epoch 10/50
# 799/804 [============================>.] - ETA: 0s - loss: 0.5498 - accuracy: 0.7316
# Epoch 00010: saving model to checkpoints/weights.10.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5498 - accuracy: 0.7315
# Epoch 11/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5486 - accuracy: 0.7324
# Epoch 12/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5481 - accuracy: 0.7332
# Epoch 13/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5482 - accuracy: 0.7337
# Epoch 14/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5480 - accuracy: 0.7326
# Epoch 15/50
# 802/804 [============================>.] - ETA: 0s - loss: 0.5466 - accuracy: 0.7339
# Epoch 00015: saving model to checkpoints/weights.15.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5468 - accuracy: 0.7337
# Epoch 16/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5471 - accuracy: 0.7339
# Epoch 17/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5467 - accuracy: 0.7334
# Epoch 18/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5466 - accuracy: 0.7343
# Epoch 19/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5461 - accuracy: 0.7336
# Epoch 20/50
# 804/804 [==============================] - ETA: 0s - loss: 0.5454 - accuracy: 0.7339
# Epoch 00020: saving model to checkpoints/weights.20.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5454 - accuracy: 0.7339
# Epoch 21/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5454 - accuracy: 0.7346
# Epoch 22/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5460 - accuracy: 0.7334
# Epoch 23/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5456 - accuracy: 0.7337
# Epoch 24/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5449 - accuracy: 0.7345
# Epoch 25/50
# 804/804 [==============================] - ETA: 0s - loss: 0.5443 - accuracy: 0.7349
# Epoch 00025: saving model to checkpoints/weights.25.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5443 - accuracy: 0.7349
# Epoch 26/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5443 - accuracy: 0.7357
# Epoch 27/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5445 - accuracy: 0.7351
# Epoch 28/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5442 - accuracy: 0.7366
# Epoch 29/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5439 - accuracy: 0.7364
# Epoch 30/50
# 804/804 [==============================] - ETA: 0s - loss: 0.5439 - accuracy: 0.7342
# Epoch 00030: saving model to checkpoints/weights.30.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5439 - accuracy: 0.7342
# Epoch 31/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5437 - accuracy: 0.7343
# Epoch 32/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5433 - accuracy: 0.7345
# Epoch 33/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5429 - accuracy: 0.7344
# Epoch 34/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5429 - accuracy: 0.7360
# Epoch 35/50
# 804/804 [==============================] - ETA: 0s - loss: 0.5425 - accuracy: 0.7355
# Epoch 00035: saving model to checkpoints/weights.35.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5425 - accuracy: 0.7355
# Epoch 36/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5424 - accuracy: 0.7358
# Epoch 37/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5426 - accuracy: 0.7357
# Epoch 38/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5427 - accuracy: 0.7352
# Epoch 39/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5423 - accuracy: 0.7342
# Epoch 40/50
# 799/804 [============================>.] - ETA: 0s - loss: 0.5417 - accuracy: 0.7362
# Epoch 00040: saving model to checkpoints/weights.40.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5420 - accuracy: 0.7360
# Epoch 41/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5421 - accuracy: 0.7354
# Epoch 42/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5420 - accuracy: 0.7372
# Epoch 43/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5419 - accuracy: 0.7353
# Epoch 44/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5411 - accuracy: 0.7364
# Epoch 45/50
# 803/804 [============================>.] - ETA: 0s - loss: 0.5413 - accuracy: 0.7370
# Epoch 00045: saving model to checkpoints/weights.45.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5412 - accuracy: 0.7372
# Epoch 46/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5417 - accuracy: 0.7359
# Epoch 47/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5416 - accuracy: 0.7356
# Epoch 48/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5413 - accuracy: 0.7372
# Epoch 49/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5416 - accuracy: 0.7360
# Epoch 50/50
# 804/804 [==============================] - ETA: 0s - loss: 0.5409 - accuracy: 0.7361
# Epoch 00050: saving model to checkpoints/weights.50.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5409 - accuracy: 0.7361

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn4.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 2022-01-01 17:31:53.733716: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 268/268 - 1s - loss: 0.5526 - accuracy: 0.7273 - 1s/epoch - 5ms/step
# Loss: 0.5526371598243713, Accuracy: 0.7273468971252441

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
n_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 160
hidden_nodes_layer2 = 80
hidden_nodes_layer3 = 40
hidden_nodes_layer4 = 20

nn5 = tf.keras.models.Sequential()

# First hidden layer
nn5.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=n_features, activation='relu'))

# Second hidden layer
nn5.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Third hidden layer
nn5.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='relu'))

# Fourth hidden layer
nn5.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation='relu'))

# Output layer
nn5.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn5.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_49 (Dense)            (None, 160)               9120
#
#  dense_50 (Dense)            (None, 80)                12880
#
#  dense_51 (Dense)            (None, 40)                3240
#
#  dense_52 (Dense)            (None, 20)                820
#
#  dense_53 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 26,081
# Trainable params: 26,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn5.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
os.makedirs('checkpoints/nn5/', exist_ok=True)

cp_callback = ModelCheckpoint(
    filepath='checkpoints/weights.{epoch:02d}.hdf5',
    verbose=1,
    save_weights_only=True,
    period=5
)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model = nn5.fit(X_train_scaled, y_train, epochs=50, callbacks=[cp_callback])
# Out:
# Epoch 1/50
# 2022-01-01 17:43:01.287027: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5667 - accuracy: 0.7233
# Epoch 2/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5519 - accuracy: 0.7312
# Epoch 3/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5496 - accuracy: 0.7340
# Epoch 4/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5475 - accuracy: 0.7338
# Epoch 5/50
# 800/804 [============================>.] - ETA: 0s - loss: 0.5458 - accuracy: 0.7359
# Epoch 00005: saving model to checkpoints/weights.05.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5458 - accuracy: 0.7359
# Epoch 6/50
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5451 - accuracy: 0.7350
# Epoch 7/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5440 - accuracy: 0.7366
# Epoch 8/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5439 - accuracy: 0.7363
# Epoch 9/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5429 - accuracy: 0.7367
# Epoch 10/50
# 802/804 [============================>.] - ETA: 0s - loss: 0.5420 - accuracy: 0.7372
# Epoch 00010: saving model to checkpoints/weights.10.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5420 - accuracy: 0.7371
# Epoch 11/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5412 - accuracy: 0.7384
# Epoch 12/50
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5403 - accuracy: 0.7379
# Epoch 13/50
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5396 - accuracy: 0.7383
# Epoch 14/50
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5392 - accuracy: 0.7386
# Epoch 15/50
# 800/804 [============================>.] - ETA: 0s - loss: 0.5396 - accuracy: 0.7391
# Epoch 00015: saving model to checkpoints/weights.15.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5395 - accuracy: 0.7392
# Epoch 16/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5388 - accuracy: 0.7388
# Epoch 17/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5386 - accuracy: 0.7396
# Epoch 18/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5384 - accuracy: 0.7400
# Epoch 19/50
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5373 - accuracy: 0.7395
# Epoch 20/50
# 801/804 [============================>.] - ETA: 0s - loss: 0.5367 - accuracy: 0.7402
# Epoch 00020: saving model to checkpoints/weights.20.hdf5
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5368 - accuracy: 0.7400
# Epoch 21/50
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5368 - accuracy: 0.7405
# Epoch 22/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5368 - accuracy: 0.7400
# Epoch 23/50
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5365 - accuracy: 0.7408
# Epoch 24/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5367 - accuracy: 0.7400
# Epoch 25/50
# 801/804 [============================>.] - ETA: 0s - loss: 0.5351 - accuracy: 0.7416
# Epoch 00025: saving model to checkpoints/weights.25.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5355 - accuracy: 0.7413
# Epoch 26/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5356 - accuracy: 0.7407
# Epoch 27/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5357 - accuracy: 0.7407
# Epoch 28/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5349 - accuracy: 0.7417
# Epoch 29/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5349 - accuracy: 0.7418
# Epoch 30/50
# 798/804 [============================>.] - ETA: 0s - loss: 0.5345 - accuracy: 0.7422
# Epoch 00030: saving model to checkpoints/weights.30.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5347 - accuracy: 0.7420
# Epoch 31/50
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5347 - accuracy: 0.7413
# Epoch 32/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5345 - accuracy: 0.7416
# Epoch 33/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5337 - accuracy: 0.7422
# Epoch 34/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5333 - accuracy: 0.7415
# Epoch 35/50
# 804/804 [==============================] - ETA: 0s - loss: 0.5337 - accuracy: 0.7409
# Epoch 00035: saving model to checkpoints/weights.35.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5337 - accuracy: 0.7409
# Epoch 36/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5335 - accuracy: 0.7426
# Epoch 37/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5324 - accuracy: 0.7416
# Epoch 38/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5325 - accuracy: 0.7430
# Epoch 39/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5323 - accuracy: 0.7426
# Epoch 40/50
# 802/804 [============================>.] - ETA: 0s - loss: 0.5326 - accuracy: 0.7425
# Epoch 00040: saving model to checkpoints/weights.40.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5324 - accuracy: 0.7426
# Epoch 41/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5322 - accuracy: 0.7431
# Epoch 42/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5318 - accuracy: 0.7430
# Epoch 43/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5319 - accuracy: 0.7426
# Epoch 44/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5312 - accuracy: 0.7432
# Epoch 45/50
# 800/804 [============================>.] - ETA: 0s - loss: 0.5323 - accuracy: 0.7432
# Epoch 00045: saving model to checkpoints/weights.45.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5322 - accuracy: 0.7434
# Epoch 46/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5317 - accuracy: 0.7427
# Epoch 47/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5309 - accuracy: 0.7432
# Epoch 48/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5311 - accuracy: 0.7428
# Epoch 49/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5310 - accuracy: 0.7431
# Epoch 50/50
# 798/804 [============================>.] - ETA: 0s - loss: 0.5311 - accuracy: 0.7432
# Epoch 00050: saving model to checkpoints/weights.50.hdf5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5310 - accuracy: 0.7434

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn5.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 2022-01-01 17:47:15.937413: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 268/268 - 1s - loss: 0.5600 - accuracy: 0.7256 - 993ms/epoch - 4ms/step
# Loss: 0.5600066781044006, Accuracy: 0.7255976796150208

# %%
# Import and read the charity_data.csv.
application_df = pd.read_csv("resources/charity_data.csv")

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])

# %%
# Determine which values to replace if counts are less than ...?
apptype_counts = application_df['APPLICATION_TYPE'].value_counts()
replace_application = list(apptype_counts[apptype_counts < 16].index)

# Replace in dataframe
for app in replace_application:
    application_df.APPLICATION_TYPE = application_df.APPLICATION_TYPE.replace(app,"Other")

# %%
# Determine which values to replace if counts are less than ..?
class_counts = application_df.CLASSIFICATION.value_counts()
replace_class = list(class_counts[class_counts < 50].index)

# Replace in dataframe
for cls in replace_class:
    application_df.CLASSIFICATION = application_df.CLASSIFICATION.replace(cls,"Other")

# %%
# Determine which values to replace if counts are less than ..?
affil_counts = application_df.AFFILIATION.value_counts()
replace_affil = list(affil_counts[affil_counts < 15000].index)

# Replace in Dataframe
for affils in replace_affil:
    application_df.AFFILIATION = application_df.AFFILIATION.replace(affils,"Other")

# %%
# Generate our categorical variable lists
application_cat = application_df.dtypes[application_df.dtypes == 'object'].index.tolist()

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(application_df[application_cat]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names_out(application_cat)

# %%
# Merge one-hot encoded features and drop the originals
application_df = application_df.merge(encode_df, left_index=True, right_index=True)
application_df = application_df.drop(columns=application_cat)

# %%
# Split our preprocessed data into our features and target arrays
y = application_df['IS_SUCCESSFUL'].values
X = application_df.drop(columns=['IS_SUCCESSFUL', 'STATUS']).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
n_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 160
hidden_nodes_layer2 = 80
# hidden_nodes_layer3 = 40
# hidden_nodes_layer4 = 20

nn6 = tf.keras.models.Sequential()

# First hidden layer
nn6.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=n_features, activation='selu'))

# Second hidden layer
nn6.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='selu'))

# # Third hidden layer
# nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='selu'))

# # Fourth hidden layer
# nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation='selu'))

# Output layer
nn6.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn6.summary()
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 160)               8640
#
#  dense_1 (Dense)             (None, 80)                12880
#
#  dense_2 (Dense)             (None, 1)                 81
#
# =================================================================
# Total params: 21,601
# Trainable params: 21,601
# Non-trainable params: 0
# _________________________________________________________________
# 2022-01-01 18:17:28.206010: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-01-01 18:17:28.206133: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Compile the model
nn6.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
os.makedirs('checkpoints/nn6/', exist_ok=True)

cp_callback = ModelCheckpoint(
    filepath='checkpoints/weights.{epoch:02d}.hdf5',
    verbose=1,
    save_weights_only=True,
    period=5
)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model = nn6.fit(X_train_scaled, y_train, epochs=50, callbacks=[cp_callback])
# Out:
# 2022-01-01 18:17:28.406152: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 1/50
# 2022-01-01 18:17:28.550467: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 804/804 [==============================] - 8s 10ms/step - loss: 0.5843 - accuracy: 0.7184
# Epoch 2/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5631 - accuracy: 0.7257
# Epoch 3/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5576 - accuracy: 0.7274
# Epoch 4/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5551 - accuracy: 0.7291
# Epoch 5/50
# 800/804 [============================>.] - ETA: 0s - loss: 0.5531 - accuracy: 0.7302
# Epoch 00005: saving model to checkpoints/weights.05.hdf5
# 804/804 [==============================] - 8s 10ms/step - loss: 0.5528 - accuracy: 0.7304
# Epoch 6/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5520 - accuracy: 0.7310
# Epoch 7/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5508 - accuracy: 0.7312
# Epoch 8/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5496 - accuracy: 0.7318
# Epoch 9/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5491 - accuracy: 0.7330
# Epoch 10/50
# 801/804 [============================>.] - ETA: 0s - loss: 0.5488 - accuracy: 0.7331
# Epoch 00010: saving model to checkpoints/weights.10.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5487 - accuracy: 0.7332
# Epoch 11/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5483 - accuracy: 0.7311
# Epoch 12/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5477 - accuracy: 0.7322
# Epoch 13/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5478 - accuracy: 0.7314
# Epoch 14/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5479 - accuracy: 0.7323
# Epoch 15/50
# 804/804 [==============================] - ETA: 0s - loss: 0.5466 - accuracy: 0.7337
# Epoch 00015: saving model to checkpoints/weights.15.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5466 - accuracy: 0.7337
# Epoch 16/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5460 - accuracy: 0.7326
# Epoch 17/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5459 - accuracy: 0.7342
# Epoch 18/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5464 - accuracy: 0.7331
# Epoch 19/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5451 - accuracy: 0.7327
# Epoch 20/50
# 799/804 [============================>.] - ETA: 0s - loss: 0.5451 - accuracy: 0.7333
# Epoch 00020: saving model to checkpoints/weights.20.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5455 - accuracy: 0.7330
# Epoch 21/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5450 - accuracy: 0.7332
# Epoch 22/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5448 - accuracy: 0.7331
# Epoch 23/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5453 - accuracy: 0.7343
# Epoch 24/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5442 - accuracy: 0.7331
# Epoch 25/50
# 799/804 [============================>.] - ETA: 0s - loss: 0.5448 - accuracy: 0.7355
# Epoch 00025: saving model to checkpoints/weights.25.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5449 - accuracy: 0.7353
# Epoch 26/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5439 - accuracy: 0.7343
# Epoch 27/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5440 - accuracy: 0.7339
# Epoch 28/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5439 - accuracy: 0.7359
# Epoch 29/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5434 - accuracy: 0.7362
# Epoch 30/50
# 804/804 [==============================] - ETA: 0s - loss: 0.5436 - accuracy: 0.7350
# Epoch 00030: saving model to checkpoints/weights.30.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5436 - accuracy: 0.7350
# Epoch 31/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5432 - accuracy: 0.7357
# Epoch 32/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5434 - accuracy: 0.7358
# Epoch 33/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5430 - accuracy: 0.7350
# Epoch 34/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5423 - accuracy: 0.7355
# Epoch 35/50
# 804/804 [==============================] - ETA: 0s - loss: 0.5425 - accuracy: 0.7354
# Epoch 00035: saving model to checkpoints/weights.35.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5425 - accuracy: 0.7354
# Epoch 36/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5432 - accuracy: 0.7355
# Epoch 37/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5416 - accuracy: 0.7346
# Epoch 38/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5422 - accuracy: 0.7354
# Epoch 39/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5421 - accuracy: 0.7363
# Epoch 40/50
# 802/804 [============================>.] - ETA: 0s - loss: 0.5418 - accuracy: 0.7366
# Epoch 00040: saving model to checkpoints/weights.40.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5418 - accuracy: 0.7365
# Epoch 41/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5418 - accuracy: 0.7356
# Epoch 42/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5418 - accuracy: 0.7354
# Epoch 43/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5414 - accuracy: 0.7358
# Epoch 44/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5418 - accuracy: 0.7365
# Epoch 45/50
# 803/804 [============================>.] - ETA: 0s - loss: 0.5414 - accuracy: 0.7353
# Epoch 00045: saving model to checkpoints/weights.45.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5413 - accuracy: 0.7354
# Epoch 46/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5414 - accuracy: 0.7365
# Epoch 47/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5409 - accuracy: 0.7345
# Epoch 48/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5416 - accuracy: 0.7354
# Epoch 49/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5410 - accuracy: 0.7352
# Epoch 50/50
# 804/804 [==============================] - ETA: 0s - loss: 0.5415 - accuracy: 0.7366
# Epoch 00050: saving model to checkpoints/weights.50.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5415 - accuracy: 0.7366

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn6.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 2022-01-01 18:23:20.932771: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 268/268 - 1s - loss: 0.5493 - accuracy: 0.7268 - 1s/epoch - 5ms/step
# Loss: 0.5492773652076721, Accuracy: 0.7267638444900513

# %%
# Import and read the charity_data.csv.
application_df = pd.read_csv("resources/charity_data.csv")

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])

# %%
# Determine which values to replace if counts are less than ...?
apptype_counts = application_df['APPLICATION_TYPE'].value_counts()
replace_application = list(apptype_counts[apptype_counts < 150].index)

# Replace in dataframe
for app in replace_application:
    application_df.APPLICATION_TYPE = application_df.APPLICATION_TYPE.replace(app,"Other")

# %%
# Determine which values to replace if counts are less than ..?
class_counts = application_df.CLASSIFICATION.value_counts()
replace_class = list(class_counts[class_counts < 700].index)

# Replace in dataframe
for cls in replace_class:
    application_df.CLASSIFICATION = application_df.CLASSIFICATION.replace(cls,"Other")

# %%
# Determine which values to replace if counts are less than ..?
affil_counts = application_df.AFFILIATION.value_counts()
replace_affil = list(affil_counts[affil_counts < 15000].index)

# Replace in Dataframe
for affils in replace_affil:
    application_df.AFFILIATION = application_df.AFFILIATION.replace(affils,"Other")

# %%
# Determine which values to replace if counts are less than ..?
usecase_counts = application_df.USE_CASE.value_counts()
replace_usecase = list(usecase_counts[usecase_counts < 5000].index)

# Replace in dataframe
for usecase in replace_usecase:
    application_df.USE_CASE = application_df.USE_CASE.replace(usecase,"Other")

# %%
# Determine which values to replace if counts are less than ..?
org_counts = application_df.ORGANIZATION.value_counts()
replace_org = list(org_counts[org_counts < 10000].index)

# Replace in dataframe
for org in replace_org:
    application_df.ORGANIZATION = application_df.ORGANIZATION.replace(org,"Other")

# %%
# Determine which values to replace if counts are less than ..?
inc_counts = application_df.INCOME_AMT.value_counts()
replace_inc = list(inc_counts[inc_counts < 3000].index)

# Replace in dataframe
for inc in replace_inc:
    application_df.INCOME_AMT = application_df.INCOME_AMT.replace(inc,"Other")

# %%
# Generate our categorical variable lists
application_cat = application_df.dtypes[application_df.dtypes == 'object'].index.tolist()

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(application_df[application_cat]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names_out(application_cat)

# %%
# Merge one-hot encoded features and drop the originals
application_df = application_df.merge(encode_df, left_index=True, right_index=True)
application_df = application_df.drop(columns=application_cat)

# %%
# Split our preprocessed data into our features and target arrays
y = application_df['IS_SUCCESSFUL'].values
X = application_df.drop(columns=['IS_SUCCESSFUL', 'STATUS']).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
n_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 160
hidden_nodes_layer2 = 80
# hidden_nodes_layer3 = 40
# hidden_nodes_layer4 = 20

nn6 = tf.keras.models.Sequential()

# First hidden layer
nn6.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=n_features, activation='selu'))

# Second hidden layer
nn6.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='selu'))

# # Third hidden layer
# nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='selu'))

# # Fourth hidden layer
# nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation='selu'))

# Output layer
nn6.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn6.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 160)               5440
#
#  dense_4 (Dense)             (None, 80)                12880
#
#  dense_5 (Dense)             (None, 1)                 81
#
# =================================================================
# Total params: 18,401
# Trainable params: 18,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn6.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
os.makedirs('checkpoints/nn6/', exist_ok=True)

cp_callback = ModelCheckpoint(
    filepath='checkpoints/weights.{epoch:02d}.hdf5',
    verbose=1,
    save_weights_only=True,
    period=5
)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model = nn6.fit(X_train_scaled, y_train, epochs=50, callbacks=[cp_callback])
# Out:
# Epoch 1/50
#   7/804 [..............................] - ETA: 6s - loss: 0.6625 - accuracy: 0.6607
# 2022-01-01 18:43:05.993314: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5888 - accuracy: 0.7163
# Epoch 2/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5684 - accuracy: 0.7207
# Epoch 3/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5635 - accuracy: 0.7254
# Epoch 4/50
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5599 - accuracy: 0.7281
# Epoch 5/50
# 802/804 [============================>.] - ETA: 0s - loss: 0.5589 - accuracy: 0.7262
# Epoch 00005: saving model to checkpoints/weights.05.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5586 - accuracy: 0.7264
# Epoch 6/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5585 - accuracy: 0.7255
# Epoch 7/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5569 - accuracy: 0.7283
# Epoch 8/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5560 - accuracy: 0.7271
# Epoch 9/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5560 - accuracy: 0.7280
# Epoch 10/50
# 803/804 [============================>.] - ETA: 0s - loss: 0.5549 - accuracy: 0.7289
# Epoch 00010: saving model to checkpoints/weights.10.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5550 - accuracy: 0.7288
# Epoch 11/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5545 - accuracy: 0.7279
# Epoch 12/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5546 - accuracy: 0.7297
# Epoch 13/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5546 - accuracy: 0.7276
# Epoch 14/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5536 - accuracy: 0.7294
# Epoch 15/50
# 804/804 [==============================] - ETA: 0s - loss: 0.5539 - accuracy: 0.7286
# Epoch 00015: saving model to checkpoints/weights.15.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5539 - accuracy: 0.7286
# Epoch 16/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5523 - accuracy: 0.7280
# Epoch 17/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5532 - accuracy: 0.7305
# Epoch 18/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5531 - accuracy: 0.7298
# Epoch 19/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5524 - accuracy: 0.7303
# Epoch 20/50
# 800/804 [============================>.] - ETA: 0s - loss: 0.5521 - accuracy: 0.7297
# Epoch 00020: saving model to checkpoints/weights.20.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5525 - accuracy: 0.7296
# Epoch 21/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5522 - accuracy: 0.7284
# Epoch 22/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5519 - accuracy: 0.7317
# Epoch 23/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5519 - accuracy: 0.7300
# Epoch 24/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5516 - accuracy: 0.7292
# Epoch 25/50
# 803/804 [============================>.] - ETA: 0s - loss: 0.5512 - accuracy: 0.7317
# Epoch 00025: saving model to checkpoints/weights.25.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5512 - accuracy: 0.7318
# Epoch 26/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5515 - accuracy: 0.7305
# Epoch 27/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5507 - accuracy: 0.7308
# Epoch 28/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5507 - accuracy: 0.7315
# Epoch 29/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5506 - accuracy: 0.7294
# Epoch 30/50
# 804/804 [==============================] - ETA: 0s - loss: 0.5501 - accuracy: 0.7308
# Epoch 00030: saving model to checkpoints/weights.30.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5501 - accuracy: 0.7308
# Epoch 31/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5504 - accuracy: 0.7312
# Epoch 32/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5502 - accuracy: 0.7320
# Epoch 33/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5503 - accuracy: 0.7305
# Epoch 34/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5495 - accuracy: 0.7300
# Epoch 35/50
# 799/804 [============================>.] - ETA: 0s - loss: 0.5498 - accuracy: 0.7304
# Epoch 00035: saving model to checkpoints/weights.35.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5495 - accuracy: 0.7306
# Epoch 36/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5496 - accuracy: 0.7318
# Epoch 37/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5493 - accuracy: 0.7298
# Epoch 38/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5492 - accuracy: 0.7311
# Epoch 39/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5494 - accuracy: 0.7307
# Epoch 40/50
# 800/804 [============================>.] - ETA: 0s - loss: 0.5493 - accuracy: 0.7309
# Epoch 00040: saving model to checkpoints/weights.40.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5491 - accuracy: 0.7311
# Epoch 41/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5494 - accuracy: 0.7344
# Epoch 42/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5491 - accuracy: 0.7321
# Epoch 43/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5489 - accuracy: 0.7315
# Epoch 44/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5488 - accuracy: 0.7315
# Epoch 45/50
# 804/804 [==============================] - ETA: 0s - loss: 0.5488 - accuracy: 0.7313
# Epoch 00045: saving model to checkpoints/weights.45.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5488 - accuracy: 0.7313
# Epoch 46/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5488 - accuracy: 0.7328
# Epoch 47/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5485 - accuracy: 0.7324
# Epoch 48/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5482 - accuracy: 0.7320
# Epoch 49/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5481 - accuracy: 0.7326
# Epoch 50/50
# 804/804 [==============================] - ETA: 0s - loss: 0.5483 - accuracy: 0.7317
# Epoch 00050: saving model to checkpoints/weights.50.hdf5
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5483 - accuracy: 0.7317

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn6.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 2022-01-01 18:48:55.452509: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 268/268 - 1s - loss: 0.5583 - accuracy: 0.7237 - 1s/epoch - 5ms/step
# Loss: 0.5582652688026428, Accuracy: 0.7237317562103271

# %%
# Import and read the charity_data.csv.
application_df = pd.read_csv("resources/charity_data.csv")

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])

# %%
# Generate our categorical variable lists
application_cat = application_df.dtypes[application_df.dtypes == 'object'].index.tolist()

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(application_df[application_cat]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names_out(application_cat)

# %%
# Merge one-hot encoded features and drop the originals
application_df = application_df.merge(encode_df, left_index=True, right_index=True)
application_df = application_df.drop(columns=application_cat)

# %%
# Split our preprocessed data into our features and target arrays
y = application_df['IS_SUCCESSFUL'].values
X = application_df.drop(columns=['IS_SUCCESSFUL']).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
n_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 160
hidden_nodes_layer2 = 120
hidden_nodes_layer3 = 80
hidden_nodes_layer4 = 40

nn7 = tf.keras.models.Sequential()

# First hidden layer
nn7.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=n_features, activation='selu'))

# Second hidden layer
nn7.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='selu'))

# Third hidden layer
nn7.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='selu'))

# Fourth hidden layer
nn7.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation='selu'))

# Output layer
nn7.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn7.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 160)               18720
#
#  dense_10 (Dense)            (None, 120)               19320
#
#  dense_11 (Dense)            (None, 80)                9680
#
#  dense_12 (Dense)            (None, 40)                3240
#
#  dense_13 (Dense)            (None, 1)                 41
#
# =================================================================
# Total params: 51,001
# Trainable params: 51,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn7.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
os.makedirs('checkpoints/nn7/', exist_ok=True)

cp_callback = ModelCheckpoint(
    filepath='checkpoints/weights.{epoch:02d}.hdf5',
    verbose=1,
    save_weights_only=True,
    period=5
)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model = nn7.fit(X_train_scaled, y_train, epochs=200, callbacks=[cp_callback])
# Out:
# Epoch 1/200
#   1/804 [..............................] - ETA: 4:10 - loss: 0.6892 - accuracy: 0.5938
# 2022-01-01 18:59:09.647608: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 804/804 [==============================] - 11s 13ms/step - loss: 0.5838 - accuracy: 0.7152
# Epoch 2/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5636 - accuracy: 0.7252
# Epoch 3/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5580 - accuracy: 0.7288
# Epoch 4/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5572 - accuracy: 0.7284
# Epoch 5/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5540 - accuracy: 0.7298
# Epoch 00005: saving model to checkpoints/weights.05.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5541 - accuracy: 0.7298
# Epoch 6/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5527 - accuracy: 0.7307
# Epoch 7/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5517 - accuracy: 0.7303
# Epoch 8/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5511 - accuracy: 0.7305
# Epoch 9/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5496 - accuracy: 0.7322
# Epoch 10/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5493 - accuracy: 0.7323
# Epoch 00010: saving model to checkpoints/weights.10.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5492 - accuracy: 0.7324
# Epoch 11/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5483 - accuracy: 0.7327
# Epoch 12/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5483 - accuracy: 0.7341
# Epoch 13/200
# 804/804 [==============================] - 11s 13ms/step - loss: 0.5474 - accuracy: 0.7327
# Epoch 14/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5456 - accuracy: 0.7360
# Epoch 15/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5461 - accuracy: 0.7349
# Epoch 00015: saving model to checkpoints/weights.15.hdf5
# 804/804 [==============================] - 11s 13ms/step - loss: 0.5462 - accuracy: 0.7348
# Epoch 16/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5453 - accuracy: 0.7342
# Epoch 17/200
# 804/804 [==============================] - 11s 13ms/step - loss: 0.5447 - accuracy: 0.7348
# Epoch 18/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5444 - accuracy: 0.7357
# Epoch 19/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5438 - accuracy: 0.7345
# Epoch 20/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5437 - accuracy: 0.7360
# Epoch 00020: saving model to checkpoints/weights.20.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5437 - accuracy: 0.7360
# Epoch 21/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5433 - accuracy: 0.7359
# Epoch 22/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5428 - accuracy: 0.7355
# Epoch 23/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5419 - accuracy: 0.7372
# Epoch 24/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5423 - accuracy: 0.7371
# Epoch 25/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5411 - accuracy: 0.7366
# Epoch 00025: saving model to checkpoints/weights.25.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5410 - accuracy: 0.7366
# Epoch 26/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5410 - accuracy: 0.7364
# Epoch 27/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5403 - accuracy: 0.7377
# Epoch 28/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5408 - accuracy: 0.7370
# Epoch 29/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5393 - accuracy: 0.7387
# Epoch 30/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5397 - accuracy: 0.7380
# Epoch 00030: saving model to checkpoints/weights.30.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5397 - accuracy: 0.7380
# Epoch 31/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5398 - accuracy: 0.7377
# Epoch 32/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5390 - accuracy: 0.7390
# Epoch 33/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5385 - accuracy: 0.7379
# Epoch 34/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5382 - accuracy: 0.7384
# Epoch 35/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5375 - accuracy: 0.7392
# Epoch 00035: saving model to checkpoints/weights.35.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5375 - accuracy: 0.7392
# Epoch 36/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5376 - accuracy: 0.7393
# Epoch 37/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5377 - accuracy: 0.7390
# Epoch 38/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5365 - accuracy: 0.7387
# Epoch 39/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5366 - accuracy: 0.7389
# Epoch 40/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5363 - accuracy: 0.7390
# Epoch 00040: saving model to checkpoints/weights.40.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5363 - accuracy: 0.7390
# Epoch 41/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5362 - accuracy: 0.7388
# Epoch 42/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5360 - accuracy: 0.7403
# Epoch 43/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5357 - accuracy: 0.7403
# Epoch 44/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5350 - accuracy: 0.7395
# Epoch 45/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5353 - accuracy: 0.7402
# Epoch 00045: saving model to checkpoints/weights.45.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5352 - accuracy: 0.7402
# Epoch 46/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5350 - accuracy: 0.7402
# Epoch 47/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5347 - accuracy: 0.7402
# Epoch 48/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5342 - accuracy: 0.7420
# Epoch 49/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5347 - accuracy: 0.7418
# Epoch 50/200
# 801/804 [============================>.] - ETA: 0s - loss: 0.5341 - accuracy: 0.7413
# Epoch 00050: saving model to checkpoints/weights.50.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5340 - accuracy: 0.7414
# Epoch 51/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5343 - accuracy: 0.7405
# Epoch 52/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5340 - accuracy: 0.7428
# Epoch 53/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5330 - accuracy: 0.7409
# Epoch 54/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5330 - accuracy: 0.7415
# Epoch 55/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5330 - accuracy: 0.7396
# Epoch 00055: saving model to checkpoints/weights.55.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5330 - accuracy: 0.7395
# Epoch 56/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5332 - accuracy: 0.7402
# Epoch 57/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5324 - accuracy: 0.7414
# Epoch 58/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5325 - accuracy: 0.7413
# Epoch 59/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5331 - accuracy: 0.7410
# Epoch 60/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5315 - accuracy: 0.7409
# Epoch 00060: saving model to checkpoints/weights.60.hdf5
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5315 - accuracy: 0.7410
# Epoch 61/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5328 - accuracy: 0.7413
# Epoch 62/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5324 - accuracy: 0.7416
# Epoch 63/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5321 - accuracy: 0.7421
# Epoch 64/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5320 - accuracy: 0.7409
# Epoch 65/200
# 800/804 [============================>.] - ETA: 0s - loss: 0.5317 - accuracy: 0.7416
# Epoch 00065: saving model to checkpoints/weights.65.hdf5
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5316 - accuracy: 0.7415
# Epoch 66/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5317 - accuracy: 0.7411
# Epoch 67/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5317 - accuracy: 0.7411
# Epoch 68/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5316 - accuracy: 0.7421
# Epoch 69/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5318 - accuracy: 0.7410
# Epoch 70/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5311 - accuracy: 0.7414
# Epoch 00070: saving model to checkpoints/weights.70.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5311 - accuracy: 0.7414
# Epoch 71/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5314 - accuracy: 0.7418
# Epoch 72/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5307 - accuracy: 0.7419
# Epoch 73/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5318 - accuracy: 0.7417
# Epoch 74/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5307 - accuracy: 0.7411
# Epoch 75/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5303 - accuracy: 0.7425
# Epoch 00075: saving model to checkpoints/weights.75.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5303 - accuracy: 0.7425
# Epoch 76/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5300 - accuracy: 0.7415
# Epoch 77/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5302 - accuracy: 0.7404
# Epoch 78/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5299 - accuracy: 0.7425
# Epoch 79/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5300 - accuracy: 0.7434
# Epoch 80/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5305 - accuracy: 0.7418
# Epoch 00080: saving model to checkpoints/weights.80.hdf5
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5305 - accuracy: 0.7418
# Epoch 81/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5297 - accuracy: 0.7425
# Epoch 82/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5294 - accuracy: 0.7416
# Epoch 83/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5305 - accuracy: 0.7412
# Epoch 84/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5293 - accuracy: 0.7435
# Epoch 85/200
# 801/804 [============================>.] - ETA: 0s - loss: 0.5297 - accuracy: 0.7418
# Epoch 00085: saving model to checkpoints/weights.85.hdf5
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5298 - accuracy: 0.7417
# Epoch 86/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5298 - accuracy: 0.7411
# Epoch 87/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5291 - accuracy: 0.7420
# Epoch 88/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5290 - accuracy: 0.7439
# Epoch 89/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5292 - accuracy: 0.7419
# Epoch 90/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5293 - accuracy: 0.7439
# Epoch 00090: saving model to checkpoints/weights.90.hdf5
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5294 - accuracy: 0.7439
# Epoch 91/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5288 - accuracy: 0.7427
# Epoch 92/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5289 - accuracy: 0.7413
# Epoch 93/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5286 - accuracy: 0.7423
# Epoch 94/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5291 - accuracy: 0.7424
# Epoch 95/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5291 - accuracy: 0.7429
# Epoch 00095: saving model to checkpoints/weights.95.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5290 - accuracy: 0.7430
# Epoch 96/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5297 - accuracy: 0.7426
# Epoch 97/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5292 - accuracy: 0.7420
# Epoch 98/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5297 - accuracy: 0.7411
# Epoch 99/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5292 - accuracy: 0.7418
# Epoch 100/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5297 - accuracy: 0.7406
# Epoch 00100: saving model to checkpoints/weights.100.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5295 - accuracy: 0.7407
# Epoch 101/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5280 - accuracy: 0.7436
# Epoch 102/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5285 - accuracy: 0.7430
# Epoch 103/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5278 - accuracy: 0.7422
# Epoch 104/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5300 - accuracy: 0.7409
# Epoch 105/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5289 - accuracy: 0.7418
# Epoch 00105: saving model to checkpoints/weights.105.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5289 - accuracy: 0.7419
# Epoch 106/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5283 - accuracy: 0.7426
# Epoch 107/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5282 - accuracy: 0.7426
# Epoch 108/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5282 - accuracy: 0.7434
# Epoch 109/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5277 - accuracy: 0.7429
# Epoch 110/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5281 - accuracy: 0.7432
# Epoch 00110: saving model to checkpoints/weights.110.hdf5
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5281 - accuracy: 0.7431
# Epoch 111/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5294 - accuracy: 0.7435
# Epoch 112/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5303 - accuracy: 0.7420
# Epoch 113/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5279 - accuracy: 0.7430
# Epoch 114/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5274 - accuracy: 0.7430
# Epoch 115/200
# 801/804 [============================>.] - ETA: 0s - loss: 0.5279 - accuracy: 0.7435
# Epoch 00115: saving model to checkpoints/weights.115.hdf5
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5279 - accuracy: 0.7435
# Epoch 116/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5278 - accuracy: 0.7424
# Epoch 117/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5278 - accuracy: 0.7431
# Epoch 118/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5279 - accuracy: 0.7423
# Epoch 119/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5277 - accuracy: 0.7429
# Epoch 120/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5274 - accuracy: 0.7425
# Epoch 00120: saving model to checkpoints/weights.120.hdf5
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5275 - accuracy: 0.7423
# Epoch 121/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5281 - accuracy: 0.7431
# Epoch 122/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5269 - accuracy: 0.7445
# Epoch 123/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5272 - accuracy: 0.7436
# Epoch 124/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5272 - accuracy: 0.7432
# Epoch 125/200
# 801/804 [============================>.] - ETA: 0s - loss: 0.5277 - accuracy: 0.7439
# Epoch 00125: saving model to checkpoints/weights.125.hdf5
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5276 - accuracy: 0.7439
# Epoch 126/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5271 - accuracy: 0.7432
# Epoch 127/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5279 - accuracy: 0.7434
# Epoch 128/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5281 - accuracy: 0.7425
# Epoch 129/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5275 - accuracy: 0.7436
# Epoch 130/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5278 - accuracy: 0.7429
# Epoch 00130: saving model to checkpoints/weights.130.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5277 - accuracy: 0.7429
# Epoch 131/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5276 - accuracy: 0.7434
# Epoch 132/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5283 - accuracy: 0.7429
# Epoch 133/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5275 - accuracy: 0.7423
# Epoch 134/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5265 - accuracy: 0.7441
# Epoch 135/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5279 - accuracy: 0.7431
# Epoch 00135: saving model to checkpoints/weights.135.hdf5
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5280 - accuracy: 0.7430
# Epoch 136/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5266 - accuracy: 0.7440
# Epoch 137/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5314 - accuracy: 0.7433
# Epoch 138/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5274 - accuracy: 0.7430
# Epoch 139/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5262 - accuracy: 0.7435
# Epoch 140/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5264 - accuracy: 0.7435
# Epoch 00140: saving model to checkpoints/weights.140.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5264 - accuracy: 0.7435
# Epoch 141/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5263 - accuracy: 0.7433
# Epoch 142/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5270 - accuracy: 0.7432
# Epoch 143/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5261 - accuracy: 0.7448
# Epoch 144/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5279 - accuracy: 0.7421
# Epoch 145/200
# 801/804 [============================>.] - ETA: 0s - loss: 0.5271 - accuracy: 0.7434
# Epoch 00145: saving model to checkpoints/weights.145.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5271 - accuracy: 0.7433
# Epoch 146/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5277 - accuracy: 0.7432
# Epoch 147/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5271 - accuracy: 0.7426
# Epoch 148/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5269 - accuracy: 0.7430
# Epoch 149/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5266 - accuracy: 0.7434
# Epoch 150/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5268 - accuracy: 0.7429
# Epoch 00150: saving model to checkpoints/weights.150.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5269 - accuracy: 0.7427
# Epoch 151/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5321 - accuracy: 0.7420
# Epoch 152/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5273 - accuracy: 0.7435
# Epoch 153/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5264 - accuracy: 0.7436
# Epoch 154/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5260 - accuracy: 0.7428
# Epoch 155/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5273 - accuracy: 0.7435
# Epoch 00155: saving model to checkpoints/weights.155.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5274 - accuracy: 0.7434
# Epoch 156/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5267 - accuracy: 0.7437
# Epoch 157/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5265 - accuracy: 0.7439
# Epoch 158/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5265 - accuracy: 0.7442
# Epoch 159/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5265 - accuracy: 0.7433
# Epoch 160/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5258 - accuracy: 0.7433
# Epoch 00160: saving model to checkpoints/weights.160.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5258 - accuracy: 0.7433
# Epoch 161/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5265 - accuracy: 0.7437
# Epoch 162/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5269 - accuracy: 0.7427
# Epoch 163/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5275 - accuracy: 0.7429
# Epoch 164/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5268 - accuracy: 0.7433
# Epoch 165/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5258 - accuracy: 0.7451
# Epoch 00165: saving model to checkpoints/weights.165.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5262 - accuracy: 0.7448
# Epoch 166/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5288 - accuracy: 0.7427
# Epoch 167/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5272 - accuracy: 0.7451
# Epoch 168/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5264 - accuracy: 0.7442
# Epoch 169/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5270 - accuracy: 0.7434
# Epoch 170/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5269 - accuracy: 0.7437
# Epoch 00170: saving model to checkpoints/weights.170.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5269 - accuracy: 0.7437
# Epoch 171/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5279 - accuracy: 0.7426
# Epoch 172/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5280 - accuracy: 0.7432
# Epoch 173/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5284 - accuracy: 0.7436
# Epoch 174/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5263 - accuracy: 0.7430
# Epoch 175/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5262 - accuracy: 0.7437
# Epoch 00175: saving model to checkpoints/weights.175.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5261 - accuracy: 0.7438
# Epoch 176/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5263 - accuracy: 0.7428
# Epoch 177/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5281 - accuracy: 0.7427
# Epoch 178/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5285 - accuracy: 0.7439
# Epoch 179/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5263 - accuracy: 0.7435
# Epoch 180/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5269 - accuracy: 0.7436
# Epoch 00180: saving model to checkpoints/weights.180.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5268 - accuracy: 0.7437
# Epoch 181/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5261 - accuracy: 0.7446
# Epoch 182/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5266 - accuracy: 0.7440
# Epoch 183/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5263 - accuracy: 0.7432
# Epoch 184/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5263 - accuracy: 0.7428
# Epoch 185/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5259 - accuracy: 0.7428
# Epoch 00185: saving model to checkpoints/weights.185.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5263 - accuracy: 0.7425
# Epoch 186/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5258 - accuracy: 0.7444
# Epoch 187/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5287 - accuracy: 0.7428
# Epoch 188/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5262 - accuracy: 0.7437
# Epoch 189/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5258 - accuracy: 0.7444
# Epoch 190/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5262 - accuracy: 0.7434
# Epoch 00190: saving model to checkpoints/weights.190.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5262 - accuracy: 0.7434
# Epoch 191/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5268 - accuracy: 0.7431
# Epoch 192/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5389 - accuracy: 0.7411
# Epoch 193/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5308 - accuracy: 0.7425
# Epoch 194/200
# 804/804 [==============================] - 10s 12ms/step - loss: 0.5255 - accuracy: 0.7439
# Epoch 195/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5261 - accuracy: 0.7436
# Epoch 00195: saving model to checkpoints/weights.195.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5260 - accuracy: 0.7437
# Epoch 196/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5259 - accuracy: 0.7426
# Epoch 197/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5257 - accuracy: 0.7430
# Epoch 198/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5265 - accuracy: 0.7427
# Epoch 199/200
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5270 - accuracy: 0.7434
# Epoch 200/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5286 - accuracy: 0.7437
# Epoch 00200: saving model to checkpoints/weights.200.hdf5
# 804/804 [==============================] - 10s 13ms/step - loss: 0.5286 - accuracy: 0.7437

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn7.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 2022-01-01 19:32:57.273867: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 268/268 - 2s - loss: 0.5815 - accuracy: 0.7273 - 2s/epoch - 6ms/step
# Loss: 0.5815345644950867, Accuracy: 0.7273468971252441

# %%
nn7.save('AlphabetSoupCharity_Optimization.h5')
